# %%
print("Hi")
print("Python learning")
# Out:
# Hi
# Python learning

# %%
#This is a comment. It will not be executed.
print("   Hi!")
# Out:
#    Hi!

# %%
#Input using input()
name=input("Enter your name:")
print("Hi!",name)
# Out:
# Enter your name: Deepika
# Hi! Deepika

# %%
#Output using print()
print("Hello World")
# Out:
# Hello World

# %%
#Variables
name="RAM"
print(name)

a="Ram"
age=21
college="ABC college"
print(a, age, college)
# Out:
# RAM
# Ram 21 ABC college

# %%
#split()
a,b=input("Enter two numbers: ").split()
print(a,b)
# Out:
# Enter two numbers:  10 20
# 10 20

# %%
##two different types of user input
i=int(input("How old are you?"))
f=float(input("Evaluate 7/2:"))
print(i,f)
# Out:
# How old are you? 20
# Evaluate 7/2: 3.5
# 20 3.5

# %%
#Read input using input()
message=input("Enter a message:")
print(message)
# Out:
# Enter a message: Python
# Python

# %%
#Assigning same value
a=b=c=10
print(a, b, c)
# Out:
# 10 10 10

# %%
#Assigning different values
x,y,z=1, 3.6, "Python"
print(x,y,z)
# Out:
# 1 3.6 Python

# %%
#Variable reassignment
x=2
y=x
y=y+4
z=10
del z   #Deleting a variable 

print(x)
print(y)
# Out:
# 2
# 6

# %%
#Swapping two variables
a,b=4,60
a,b=b,a
print(a,b)
# Out:
# 60 4

# %%
#Counting characters in a string
name="Deepika"
length=len(name)
print("Length of the word:",length)
# Out:
# Length of the word: 7

# %%
#Type casting
age="20"
age=int(age)
print(age+5)
print(type(age))
# Out:
# 25
# <class 'int'>

# %%
#implicit type conversion 
a=7
print(type(a))

b=3.0
print(type(b))

c=a+b
print(c)
print(type(c))

d=a*b
print(d)
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# 10.0
# <class 'float'>
# 21.0
# <class 'float'>

# %%
#Convert int to float
a=5
n=float(a)

print(n)
print(type(n))
# Out:
# 5.0
# <class 'float'>

# %%
#Convert float to int
a=5.3
n=int(a)

print(n)
print(type(n))
# Out:
# 5
# <class 'int'>

# %%
#Convert int to string
a=5
n=str(a)

print(n)
print(type(n))
# Out:
# 5
# <class 'str'>

# %%
#Convert string to float
a="5.2"
n=float(a)

print(n)
print(type(n))
# Out:
# 5.2
# <class 'float'>

# %%
#Convert string to int
a="1"
n=int(a)

print(n)
print(type(n))
# Out:
# 1
# <class 'int'>

# %%
#adding string and integer 
a=3
b='8'

c=a+int(b)
print(c)
print(type(c))
# Out:
# 11
# <class 'int'>

# %%
#type() function
a=5
b="Hi"
c=[1,2]

print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'list'>

# %%
#compare the types of two variables
x=10
y=2.3
z=2

print(type(x) is type(y))
print(type(x) is type(z))
# Out:
# False
# True

# %%
#Insert a variable into a string or f-strings
name="Deepika"
print(f"Hello, {name}!")

a="Python"
res=f"This is {a} programming!"
print(res)

name="Deepika"
age=20
print(f"{name} will be {age+1} next year.")

name=input("Enter your name:")
print(f"Hi! {name}")
# Out:
# Hello, Deepika!
# This is Python programming!
# Deepika will be 21 next year.
# Enter your name: Ram
# Hi! Ram

# %%
#using format()
a="Hello"
b="world"

res="{} {}".format(a,b)
print(res)

name="Deepika"
age=20
print("Name: {name},Age:{age}".format(name=name,age=age))
# Out:
# Hello world
# Name: Deepika,Age:20

# %%
#using+operator
a="Hello"
b="World"

res=a+" "+b
print(res)
# Out:
# Hello World

# %%
#using %formatting
a="Python"
res="This is %s programming!" %a
print(res)

b=10
res="My age %i"%b
print(res)
# Out:
# This is Python programming!
# My age 10

# %%
#Formatting numeric values with %
score=99
percentage=97.87

print("Score: %d" %score)
print("Percentage: %.2f%%" %percentage)
# Out:
# Score: 99
# Percentage: 97.87%
